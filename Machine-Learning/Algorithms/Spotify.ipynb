# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("spotify.csv" , encoding='latin-1')

# %%
df.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
X = df.drop(['Popularity' , 'Track.Name'] , axis = 1)

# %%
y = df['Popularity']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(criterion = "gini", 
            random_state = 100,max_depth=3, min_samples_leaf=5)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
le = LabelEncoder()

# %%
int_genre = le.fit_transform(df['Genre'])

# %%
integ.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-8901b9e41583> in <module>
# ----> 1 integ.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
int_genre
# Out:
# array([ 6, 19,  8, 15,  9, 15, 20, 15,  7, 11, 18,  8, 15, 14,  5,  8, 13,
#         9,  5, 12, 16,  7, 19, 13, 11,  6,  1,  5, 13, 13, 10,  8, 18,  0,
#         8,  2, 14, 15,  3,  8, 10,  8,  8, 15, 17,  4, 13,  4, 10, 15])

# %%
int_artist = le.fit_transform(df['Artist.Name'])

# %%
int_artist
# Out:
# array([32,  1,  2,  9, 28,  9, 20, 30, 19,  4,  3,  6, 18, 31,  8,  5, 10,
#        28, 36, 21, 23, 19, 11, 22,  4, 32, 35,  0,  7, 10, 34,  2, 24, 37,
#        13, 26, 31,  9, 12, 17, 15, 33, 16, 14, 29, 25, 27, 25, 34,  9])

# %%
df['Artist.Name'] = int_artist

# %%
df.head()
# Out:
#    Unnamed: 0                       Track.Name  Artist.Name           Genre  \
# 0           1                         Señorita           32    canadian pop
# 1           2                            China            1  reggaeton flow
# 2           3    boyfriend (with Social House)            2       dance pop
# 3           4  Beautiful People (feat. Khalid)            9             pop
# 4           5      Goodbyes (Feat. Young Thug)           28         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
df['Genre'] = int_genre

# %%
df.head()
# Out:
#    Unnamed: 0                       Track.Name  Artist.Name  Genre  \
# 0           1                         Señorita           32      6
# 1           2                            China            1     19
# 2           3    boyfriend (with Social House)            2      8
# 3           4  Beautiful People (feat. Khalid)            9     15
# 4           5      Goodbyes (Feat. Young Thug)           28      9
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# ...

# %%
X = df.drop(['Track.Name' , 'Popularity'] , axis = 1)

# %%
y = df['Popularity']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
dt = DecisionTreeClassifier(criterion = "gini", 
            random_state = 100,max_depth=3, min_samples_leaf=5)

# %%
dt_model = dt.fit(X_train , y_train)

# %%
y_test.shape
# Out:
# (17,)

# %%
from np import array
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-55-d5c81fa93e5f> in <module>
# ----> 1 from np import array
#
# ModuleNotFoundError: No module named 'np'

# %%
from numpy import array

# %%
y_value = array(df['Popularity'])

# %%
y_value = y_value.reshape(-1 , 1)

# %%
X_train
# Out:
#     Unnamed: 0  Artist.Name  Genre  Beats.Per.Minute  Energy  Danceability  \
# 46          47           27     13               176      75            67
# 47          48           25      4               100      79            69
# 15          16            5      8                93      45            70
# 9           10            4     11               135      43            70
# 16          17           10     13               176      65            75
# 24          25            4     11               135      45            67
# 34          35           13      8               100      88            77
# 31          32            2      8               140      32            78
# 0            1           32      6               117      55            76
# 44          45           29     17                98      69            88
# 27          28            0      5                96      46            73
# ...

# %%
y_value
# Out:
# array([[79],
#        [92],
#        [85],
#        [86],
#        [94],
#        [84],
#        [92],
#        [90],
#        [87],
#        [95],
#        [93],
#        [86],
#        [88],
#        [87],
#        [92],
#        [82],
#        [90],
#        [91],
#        [88],
#        [91],
#        [91],
#        [91],
#        [83],
#        [91],
#        [89],
#        [70],
#        [83],
#        [89],
#        [91],
#        [89],
#        [84],
#        [89],
#        [89],
#        [89],
#        [89],
#        [89],
#        [91],
#        [87],
#        [80],
#        [78],
#        [88],
#        [90],
#        [87],
#        [84],
#        [88],
#        [88],
#        [88],
#        [88],
#        [88],
#        [82]], dtype=int64)

# %%
y_final = pd.DataFrame(y_value)

# %%
y_final.head()
# Out:
#     0
# 0  79
# 1  92
# 2  85
# 3  86
# 4  94

# %%
y_final.shape
# Out:
# (50, 1)

# %%
y_test.shape
# Out:
# (17,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_final, test_size=0.33, random_state=42)

# %%
dt = DecisionTreeClassifier(criterion = "gini", 
            random_state = 100,max_depth=3, min_samples_leaf=5)

# %%
dt_final = dt.fit(X_train , y_train)

# %%
X.head()
# Out:
#    Unnamed: 0  Artist.Name  Genre  Beats.Per.Minute  Energy  Danceability  \
# 0           1           32      6               117      55            76
# 1           2            1     19               105      81            79
# 2           3            2      8               190      80            40
# 3           4            9     15                93      65            64
# 4           5           28      9               150      65            58
#
#    Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  Speechiness.
# 0              -6         8        75      191               4             3
# 1              -4         8        61      302               8             9
# 2              -4        16        70      186              12            46
# 3              -8         8        55      198              12            19
# 4              -4        11        18      175              45             7

# %%
pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-c6fc79dbd350> in <module>
# ----> 1 pred
#
# NameError: name 'pred' is not defined

# %%
dt = DecisionTreeRegressor()

# %%
dt_model = dt.fit(X_train , y_train)

# %%
y
# Out:
# 0     79
# 1     92
# 2     85
# 3     86
# 4     94
# 5     84
# 6     92
# 7     90
# 8     87
# 9     95
# 10    93
# 11    86
# 12    88
# 13    87
# 14    92
# 15    82
# 16    90
# 17    91
# 18    88
# 19    91
# 20    91
# 21    91
# 22    83
# 23    91
# 24    89
# 25    70
# 26    83
# 27    89
# 28    91
# 29    89
# 30    84
# 31    89
# 32    89
# 33    89
# 34    89
# 35    89
# 36    91
# 37    87
# 38    80
# 39    78
# 40    88
# 41    90
# 42    87
# 43    84
# 44    88
# 45    88
# 46    88
# 47    88
# 48    88
# 49    82
# Name: Popularity, dtype: int64

# %%
y.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-2727d4ac428e> in <module>
# ----> 1 y.type
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'type'

# %%
y_final
# Out:
#      0
# 0   79
# 1   92
# 2   85
# 3   86
# 4   94
# 5   84
# 6   92
# 7   90
# 8   87
# 9   95
# 10  93
# 11  86
# 12  88
# 13  87
# 14  92
# 15  82
# 16  90
# 17  91
# 18  88
# 19  91
# 20  91
# 21  91
# 22  83
# 23  91
# 24  89
# 25  70
# 26  83
# 27  89
# 28  91
# 29  89
# 30  84
# 31  89
# 32  89
# 33  89
# 34  89
# 35  89
# 36  91
# 37  87
# 38  80
# 39  78
# 40  88
# 41  90
# 42  87
# 43  84
# 44  88
# 45  88
# 46  88
# 47  88
# 48  88
# 49  82

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
dt = DecisionTreeClassifier(criterion = "gini", 
            random_state = 100,max_depth=3, min_samples_leaf=5)

# %%
dt_final = dt.fit(X_train , y_train)

# %%
pred = dt_model.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test , pred))
# Out:
#               precision    recall  f1-score   support
#
#         70.0       0.00      0.00      0.00         1
#         78.0       0.00      0.00      0.00         1
#         83.0       0.00      0.00      0.00         1
#         84.0       0.00      0.00      0.00         1
#         85.0       0.00      0.00      0.00         0
#         86.0       0.00      0.00      0.00         1
#         87.0       0.00      0.00      0.00         3
#         88.0       0.50      0.67      0.57         3
#         89.0       0.00      0.00      0.00         1
#         90.0       0.00      0.00      0.00         1
#         91.0       0.50      1.00      0.67         2
#         92.0       0.50      1.00      0.67         1
#         94.0       0.00      0.00      0.00         1
#         95.0       0.00      0.00      0.00         0
#
#     accuracy                           0.29        17
#    macro avg       0.11      0.19      0.14        17
# ...
